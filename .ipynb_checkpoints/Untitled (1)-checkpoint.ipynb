# %%
import sqlite3
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
conn = sqlite3.connect("database.sqlite")

# %%
user_df = pd.read_sql_query("select * from user;", conn)
grade_df = pd.read_sql_query("select * from grade;", conn)
method_df = pd.read_sql_query("select * from method;", conn)
ascent_df = pd.read_sql_query("select * from ascent;", conn)

# %%
user_df.rename(columns = {'id':'user_id'}, inplace=True)

# %%
sns.distplot(ascent_df['grade_id'],15)

# %%
# ascent_count_df = ascent_df.groupby('grade_id').count()
# ascent_count_df = ascent_count_df['id']
# ascent_count_df = pd.DataFrame(ascent_count_df)

# %%
df = pd.merge(user_df,ascent_df, on='user_id')

# %%
ascent_df
# Out:
#               id  user_id  grade_id notes  raw_notes  method_id  climb_type  \
# 0              2        1        36                0          3           0
# 1              3        1        36                0          3           0
# 2              4        1        36                0          3           0
# 3              5        1        36                0          3           0
# 4              6        1        36                0          3           0
# ...          ...      ...       ...   ...        ...        ...         ...
# 4111872  4910370    59627        46                0          1           0
# 4111873  4910371    44075        49                0          1           0
# 4111874  4910376    19098        51                0          3           0
# 4111875  4910379    19098        57                0          3           0
# 4111876  4910381    24751        62                0          1           1
#
#          total_score        date  year  ...  country  \
# ...

# %%
grade_df
# Out:
#     id  score fra_routes  fra_routes_input  fra_routes_selector fra_boulders  \
# 0    1      0          -                 1                    1            -
# 1    2      0          1                 0                    0            1
# 2    3      0         1a                 0                    0           1A
# 3    4      0         1b                 0                    0           1B
# 4    5      0         1c                 0                    0           1C
# ..  ..    ...        ...               ...                  ...          ...
# 78  82   1475     9b+/9c                 0                    0       9B+/9C
# 79  83   1500         9c                 0                    0           9C
# 80  84   1525       9c/+                 0                    0         9C/+
# 81  85   1550        9c+                 0                    0          9C+
# 82  86   1575    9c+/10a                 0                    0      9C+/10A
#
# ...

# %%
top_grades = df[(df['grade_id'] == 70)]

# %%
top_grades
# Out:
#          user_id first_name last_name      city country_x  sex  height  \
# 5168          38      first      last   Glasgow       GBR    0     178
# 5196          38      first      last   Glasgow       GBR    0     178
# 5216          38      first      last   Glasgow       GBR    0     178
# 5258          38      first      last   Glasgow       GBR    0     178
# 5298          38      first      last   Glasgow       GBR    0     178
# ...          ...        ...       ...       ...       ...  ...     ...
# 4104571    66466      first      last   Tutzing       DEU    0     170
# 4104683    66466      first      last   Tutzing       DEU    0     170
# 4104692    66466      first      last   Tutzing       DEU    0     170
# 4104797    66468      first      last   Sondrio       ITA    0     185
# 4110018    66925      first      last  Badalona       ESP    0       0
#
#          weight  started      competitions  ... country_y  \
# ...

# %%
top_grades = top_grades[['user_id', 'city', 'country_x', 'sex', 'height', 'weight', 'started']]

# %%
sns.pairplot(top_grades, hue='sex')

# %%
ascent_df.country.unique()
# Out:
# array(['THA', '', 'SWE', 'AUS', 'NOR', 'FRA', 'LUX', 'ESP', 'BEL', 'USA',
#        'ITA', 'AUT', 'ZAF', 'NZL', 'DEU', 'CAN', 'GBR', 'POL', 'SVN',
#        'IND', 'HUN', 'HRV', 'COL', 'CHE', 'CZE', 'FIN', 'PRT', 'MEX',
#        'GRC', 'HKG', 'SVK', 'BRA', 'SRB', 'BGR', 'NLD', 'UKR', 'ISR',
#        'MAR', 'JPN', 'ABW', 'TUR', 'ROM', 'IRL', 'CHN', 'VNM', 'EGY',
#        'SDN', 'ETH', 'ZWE', 'PER', 'MYS', 'CHL', 'VEN', 'ISL', 'RUS',
#        'AND', 'TWN', 'BOL', 'ARG', 'IRN', 'NPL', 'CUB', 'DNK', 'GIB',
#        'REU', 'MLT', 'YUG', 'KOR', 'ALB', 'KEN', 'MDG', 'PAK', 'NAM',
#        'MSR', 'URY', 'OMN', 'LAO', 'FXX', 'HND', 'MLI', 'PHL', 'MKD',
#        'ATF', 'SLV', 'CRI', 'GUM', 'MCO', 'HTI', 'GTM', 'EST', 'ECU',
#        'TJK', 'MNE', 'BIH', 'SWZ', 'KGZ', 'CYP', 'IDN', 'JOR', 'LBN',
#        'KIR', 'DJI', 'CPV', 'FLK', 'SYC', 'VGB', 'BMU', 'WSM', 'AIA',
#        'MTQ', 'ARE', 'LTU', 'SMR', 'KAZ', 'SYR', 'MAC', 'TMP', 'PRI',
# ...

# %%
canadian_df = ascent_df.loc[ascent_df['country'] == 'CAN']
spanish_df = ascent_df.loc[ascent_df['country'] == 'ESP']

# %%
spanish_df
# Out:
#               id  user_id  grade_id notes  raw_notes  method_id  climb_type  \
# 200          303       18        51                0          3           0
# 212          351       18        49                0          1           0
# 213          352       18        51                0          3           0
# 214          353       18        49                0          3           0
# 215          354       18        49                0          3           0
# ...          ...      ...       ...   ...        ...        ...         ...
# 4111823  4910261    28983        64                0          1           0
# 4111824  4910262    28983        64                0          1           0
# 4111825  4910263    28983        62                0          3           0
# 4111835  4910273     8458        38                0          3           0
# 4111876  4910381    24751        62                0          1           1
#
#          total_score        date  year  ...  country  \
# ...

# %%
ax = sns.distplot(canadian_df['grade_id'],15)
sns.distplot(spanish_df['grade_id'],15, ax=ax)
